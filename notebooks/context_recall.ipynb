# %%
from dotenv import load_dotenv
load_dotenv()

from openai import AsyncOpenAI
from ragas.llms import llm_factory
from ragas.metrics.collections import ContextRecall

client = AsyncOpenAI()
llm = llm_factory("gpt-5-mini", client=client)

scorer = ContextRecall(llm=llm)

# %%
# Example 1: Contexts cover symptoms but miss the cause (insulin resistance / obesity)
result = await scorer.ascore(
    user_input="What are the symptoms and causes of Type 2 diabetes?",
    retrieved_contexts=[
        "Type 2 diabetes symptoms include frequent urination and excessive thirst.",
        "People with Type 2 diabetes often experience fatigue and blurred vision."
    ],
    reference="Type 2 diabetes is caused by insulin resistance, often linked to obesity and a sedentary lifestyle. Its symptoms include frequent urination, excessive thirst, fatigue, blurred vision, and slow-healing sores."
)
print(f"Context Recall Score: {result.value}")
# Out:
# API call failed on attempt 1: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# Max retries exceeded. Total attempts: 1, Last error: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/instructor/v2/core/retry.py:419, in retry_async_v2(func, response_model, provider, mode, context, max_retries, args, kwargs, strict, hooks)
#     418 try:
# --> 419     async for attempt in max_retries_instance:
#     420         with attempt:
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/tenacity/asyncio/__init__.py:170, in AsyncRetrying.__anext__(self)
#     169 while True:
# --> 170     do = await self.iter(retry_state=self._retry_state)
#     171     if do is None:
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/tenacity/asyncio/__init__.py:157, in AsyncRetrying.iter(self, retry_state)
#     156 for action in self.iter_state.actions:
# --> 157     result = await action(retry_state)
#     158 return result
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/tenacity/_utils.py:111, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#     110 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# --> 111     return call(*args, **kwargs)
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.5/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/instructor/v2/core/retry.py:428, in retry_async_v2(func, response_model, provider, mode, context, max_retries, args, kwargs, strict, hooks)
#     427 try:
# --> 428     response = await func(*args, **kwargs)
#     429 except IncompleteOutputException:
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/openai/resources/chat/completions/completions.py:2814, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2813 validate_response_format(response_format)
# -> 2814 return await self._post(
#    2815     "/chat/completions",
#    2816     body=await async_maybe_transform(
#    2817         {
#    2818             "messages": messages,
#    2819             "model": model,
#    2820             "audio": audio,
#    2821             "frequency_penalty": frequency_penalty,
#    2822             "function_call": function_call,
#    2823             "functions": functions,
#    2824             "logit_bias": logit_bias,
#    2825             "logprobs": logprobs,
#    2826             "max_completion_tokens": max_completion_tokens,
#    2827             "max_tokens": max_tokens,
#    2828             "metadata": metadata,
#    2829             "modalities": modalities,
#    2830             "moderation": moderation,
#    2831             "n": n,
#    2832             "parallel_tool_calls": parallel_tool_calls,
#    2833             "prediction": prediction,
#    2834             "presence_penalty": presence_penalty,
#    2835             "prompt_cache_key": prompt_cache_key,
#    2836             "prompt_cache_retention": prompt_cache_retention,
#    2837             "reasoning_effort": reasoning_effort,
#    2838             "response_format": response_format,
#    2839             "safety_identifier": safety_identifier,
#    2840             "seed": seed,
#    2841             "service_tier": service_tier,
#    2842             "stop": stop,
#    2843             "store": store,
#    2844             "stream": stream,
#    2845             "stream_options": stream_options,
#    2846             "temperature": temperature,
#    2847             "tool_choice": tool_choice,
#    2848             "tools": tools,
#    2849             "top_logprobs": top_logprobs,
#    2850             "top_p": top_p,
#    2851             "user": user,
#    2852             "verbosity": verbosity,
#    2853             "web_search_options": web_search_options,
#    2854         },
#    2855         completion_create_params.CompletionCreateParamsStreaming
#    2856         if stream
#    2857         else completion_create_params.CompletionCreateParamsNonStreaming,
#    2858     ),
#    2859     options=make_request_options(
#    2860         extra_headers=extra_headers,
#    2861         extra_query=extra_query,
#    2862         extra_body=extra_body,
#    2863         timeout=timeout,
#    2864         security={"bearer_auth": True},
#    2865     ),
#    2866     cast_to=ChatCompletion,
#    2867     stream=stream or False,
#    2868     stream_cls=AsyncStream[ChatCompletionChunk],
#    2869 )
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/openai/_base_client.py:1931, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1928 opts = FinalRequestOptions.construct(
#    1929     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1930 )
# -> 1931 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/openai/_base_client.py:1716, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1715     log.debug("Re-raising status error")
# -> 1716     raise self._make_status_error_from_response(err.response) from None
#    1718 break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# The above exception was the direct cause of the following exception:
#
# InstructorRetryException                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Example 1: Contexts cover symptoms but miss the cause (insulin resistance / obesity)
# ----> 2 result = await scorer.ascore(
#       3     user_input="What are the symptoms and causes of Type 2 diabetes?",
#       4     retrieved_contexts=[
#       5         "Type 2 diabetes symptoms include frequent urination and excessive thirst.",
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/ragas/metrics/collections/context_recall/metric.py:119, in ContextRecall.ascore(self, user_input, retrieved_contexts, reference)
#     116 prompt_string = self.prompt.to_string(input_data)
#     118 # Get classifications from LLM
# --> 119 result = await self.llm.agenerate(prompt_string, ContextRecallOutput)
#     121 # Calculate score
#     122 if not result.classifications:
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/ragas/llms/base.py:1109, in InstructorLLM.agenerate(self, prompt, response_model)
#    1101     result = await self.client.create(
#    1102         model=self.model,
#    1103         messages=messages,
#    1104         response_model=response_model,
#    1105         **provider_kwargs,
#    1106     )
#    1107 else:
#    1108     # OpenAI, Anthropic, LiteLLM
# -> 1109     result = await self.client.chat.completions.create(
#    1110         model=self.model,
#    1111         messages=messages,
#    1112         response_model=response_model,
#    1113         **provider_kwargs,
#    1114     )
#    1116 # Track the usage
#    1117 track(
#    1118     LLMUsageEvent(
#    1119         provider=self.provider,
#    (...)   1124     )
#    1125 )
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/instructor/v2/core/client.py:798, in AsyncInstructor.create(self, response_model, messages, max_retries, context, strict, hooks, **kwargs)
#     782 if (
#     783     get_origin(response_model) in {Iterable}
#     784     and get_args(response_model)
#     785     and get_args(response_model)[0] is not None
#     786     and self.mode not in Mode.parallel_modes()
#     787 ):
#     788     return self.create_iterable(
#     789         messages=messages,
#     790         response_model=get_args(response_model)[0],
#    (...)    795         **kwargs,
#     796     )
# --> 798 return await self.create_fn(
#     799     response_model=response_model,
#     800     context=context,
#     801     max_retries=max_retries,
#     802     messages=messages,
#     803     strict=strict,
#     804     hooks=combined_hooks,
#     805     **kwargs,
#     806 )
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/instructor/v2/core/patch.py:364, in _create_async_wrapper.<locals>.new_create_async(response_model, context, max_retries, strict, hooks, *args, **kwargs)
#     361             return cached  # type: ignore[return-value]
#     363 # Use v2 retry logic with registry handlers
# --> 364 response = await retry_async_v2(
#     365     func=func,
#     366     response_model=response_model,
#     367     provider=provider,
#     368     mode=mode,
#     369     context=context,
#     370     max_retries=max_retries,
#     371     args=args,
#     372     kwargs=new_kwargs,
#     373     strict=strict,
#     374     hooks=hooks,
#     375 )
#     377 # Store in cache after successful call
#     378 if cache is not None and response_model is not None:
#
# File ~/Desktop/Project/personal/RAGAS/venv/lib/python3.14/site-packages/instructor/v2/core/retry.py:524, in retry_async_v2(func, response_model, provider, mode, context, max_retries, args, kwargs, strict, hooks)
#     514     if hooks:
#     515         hooks.emit_completion_last_attempt(
#     516             last_exception,
#     517             **_attempt_metadata(
#    (...)    521             ),
#     522         )
# --> 524     raise InstructorRetryException(
#     525         str(last_exception),
#     526         last_completion=failed_attempts[-1].completion if failed_attempts else None,
#     527         n_attempts=last_attempt_number,
#     528         total_usage=total_usage,
#     529         messages=extract_messages(kwargs),
#     530         create_kwargs=kwargs,
#     531         failed_attempts=failed_attempts,
#     532     ) from last_exception
#     534 # Should never reach here
#     535 logger.error("Unexpected code path in retry_async_v2")
#
# InstructorRetryException: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
# Example 2 : The retrieved context fully covers every claim in the ground truth
result = await scorer.ascore(
    user_input="Where is the Eiffel Tower located?",
    retrieved_contexts=[
        "The Eiffel Tower is a wrought-iron lattice tower located on the Champ de Mars in Paris, France."
    ],
    reference="The Eiffel Tower is located in Paris, France."
)
print(f"Context Recall Score: {result.value}")
